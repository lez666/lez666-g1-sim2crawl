# %%
ARMATURE_5020 = 0.003609725
ARMATURE_7520_14 = 0.010177520
ARMATURE_7520_22 = 0.025101925
ARMATURE_4010 = 0.00425

NATURAL_FREQ = 10 * 2.0 * 3.1415926535  # 10Hz
DAMPING_RATIO = 2.0

STIFFNESS_5020 = ARMATURE_5020 * NATURAL_FREQ**2
STIFFNESS_7520_14 = ARMATURE_7520_14 * NATURAL_FREQ**2
STIFFNESS_7520_22 = ARMATURE_7520_22 * NATURAL_FREQ**2
STIFFNESS_4010 = ARMATURE_4010 * NATURAL_FREQ**2

DAMPING_5020 = 2.0 * DAMPING_RATIO * ARMATURE_5020 * NATURAL_FREQ
DAMPING_7520_14 = 2.0 * DAMPING_RATIO * ARMATURE_7520_14 * NATURAL_FREQ
DAMPING_7520_22 = 2.0 * DAMPING_RATIO * ARMATURE_7520_22 * NATURAL_FREQ
DAMPING_4010 = 2.0 * DAMPING_RATIO * ARMATURE_4010 * NATURAL_FREQ

print(f"STIFFNESS_5020: {STIFFNESS_5020}")
print(f"STIFFNESS_7520_14: {STIFFNESS_7520_14}")
print(f"STIFFNESS_7520_22: {STIFFNESS_7520_22}")
print(f"STIFFNESS_4010: {STIFFNESS_4010}")

print(f"DAMPING_5020: {DAMPING_5020}")
print(f"DAMPING_7520_14: {DAMPING_7520_14}")
print(f"DAMPING_7520_22: {DAMPING_7520_22}")
print(f"DAMPING_4010: {DAMPING_4010}")


print(f"ARMATURE_5020: {ARMATURE_5020}")
print(f"ARMATURE_7520_14: {ARMATURE_7520_14}")
print(f"ARMATURE_7520_22: {ARMATURE_7520_22}")
print(f"ARMATURE_4010: {ARMATURE_4010}")
# Out:
# STIFFNESS_5020: 14.25062309787429
# STIFFNESS_7520_14: 40.17923847137318
# STIFFNESS_7520_22: 99.09842777666113
# STIFFNESS_4010: 16.77832748089279
# DAMPING_5020: 0.907222843292423
# DAMPING_7520_14: 2.5578897650279457
# DAMPING_7520_22: 6.3088018534966395
# DAMPING_4010: 1.06814150219
# ARMATURE_5020: 0.003609725
# ARMATURE_7520_14: 0.01017752
# ARMATURE_7520_22: 0.025101925
# ARMATURE_4010: 0.00425
